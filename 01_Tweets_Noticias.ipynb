# %% [markdown]
# # Notícias e Tweets Eleições

# %%
import ipy_table
import re
# %run ../aux/postgres.py
# Out:
# postgres functions loaded...

# %%
cmd = ("SELECT observacao, count(*) " +
       "FROM public.analisetweet " +
       "WHERE codanaliseamostra = 121 " +
       "group by 1 " +
       "order by 1")
res = query(cmd)
res
# Out:
# [('not01', 1920),
#  ('not02', 9),
#  ('not03', 9199),
#  ('not04', 2130),
#  ('not05', 42),
#  ('not06', 181662),
#  ('not06;not08', 135),
#  ('not06;not10', 2),
#  ('not07', 56),
#  ('not08', 10580),
#  ('not09', 1110),
#  ('not10', 478),
#  ('not11', 30),
#  ('not12', 1),
#  ('not13', 1)]

# %%
cmd = ("select t.text, am.similaridade " +
        "from tweet t inner join amostratweet am on am.codtweet = t.codtweet " +
       "where am.codamostra = 101 and similaridade > 0.24  limit 100")
tweets = query(cmd)
print(len(tweets))
# Out:
# 100

# %%
tweets
# Out:
# [('RT @Comprova: 6 | É falsa a inscrição preconceituosa sobre nordestinos em camisa de filho de Bolsonaro | https://t.co/MR9p9jmwvy',
#   0.242938),
#  ('A atriz global Luma Costa se envolveu em uma polêmica no último fim de semana ao contestar a campanha #EleNão , contrária à candidatura de Jair Bolsonaro (PSL) à presidência. Pelas redes sociais, Luma chegou a dizer que as mulheres participantes do ato são “burras”.  pic.twitter.com/CA4wPbayta',
#   0.256293),
#  ('A manifestação #EleNão  em repúdio ao candidato a presidente Jair Bolsonaro, que se espalhou por cidades brasileiras neste sábado, foi a maior manifestação de mulheres na história do Brasil. Foi também das maiores manifestações contra um candidato, independentemente das mulheres.',
#   0.24505),
# ...

# %% [markdown]
# # Notícia 01:
#
# É falsa a inscrição preconceituosa sobre nordestinos em camisa de filho de Bolsonaro

# %%
cod = 'not01'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 1920
#
# A camisa do Bozinho sobre os nordestinos é fake, mas com certeza já animou muito eleitor dele a fazer uma igual
# ---
# Gente é fake essa camisa do filho do bozo sobre nordestinos. Tem essa foto em que ele e o pai estão com a mesma rou… https://t.co/uBWoAXjQWI
# ---
# @andrealobrasil Com declarações em camisa ou não, as declarações verbais do coiso em absurdo preconceito ao nordest… https://t.co/Vq0zu2ne4u
# ---
# Povo lindo Rafael Fernandes me informou que a tal camisa do filhote de cruz credo falando mal dos nordestinos era f… https://t.co/K2k4fUjuAK
# ---
# @anterogreco NORDESTINOS  OLHA  O QUE ESTÁ  ESCRITO NA  CAMISA  DO FILHO DE BOLSONARO........E SE NORDESTINO TEM VE… https://t.co/8q3idOhZMn
# ---
# @MidiaNINJA NORDESTINOS  OLHA  O QUE ESTÁ  ESCRITO NA  CAMISA  DO FILHO DE BOLSONARO........E SE NORDESTINO TEM VER… https://t.co/axBOMZtimC
# ---
# ...

# %% [markdown]
# # Notícia 02:
#
# #Verificamos: Bolsonaro não disse que ‘paciente com câncer custa caro para o Estado’ e que vai ‘cortar essa farra’

# %%
cod = 'not02'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 9
#
# Bolsonaro não disse que ‘paciente com câncer custa caro para o Estado’ e que vai ‘cortar essa farra’. Leia em:… https://t.co/nWyPHFiBHS
# ---
# [Agência Lupa] Bolsonaro não disse que ‘paciente com câncer custa caro para o Estado’ e que vai ‘cortar essa farra’ https://t.co/Jsi6FZYcH0
# ---
# Câncer e Aids são farras?????Onde vamos parar com esse coiso, cada dia mais louco?. AFF!!!!
# ---
# RT @Amarulacarvalho: Câncer e Aids são farras?????Onde vamos parar com esse coiso, cada dia mais louco?. AFF!!!! https://t.co/fxOYKrlUJV
# ---
# 01 - Bolsonaro não disse que ‘paciente com câncer custa caro para o Estado’ e que vai ‘cortar essa farra’
# https://t.co/6P5X3Hhgx6
# ---
# Ontem eu vi gente compartilhando a seguinte FAKE NEWS:
# "Paciente com câncer custa caro para o Estado. Vamos cortar essa farra".
# ---
# RT @Amarulacarvalho: Câncer e Aids são farras?????Onde vamos parar com esse coiso, cada dia mais louco?. AFF!!!! https://t.co/fxOYKrlUJV
# ---
# ...

# %% [markdown]
# # Notícia 03:
#
# Post com propostas atribuídas a Bolsonaro mistura informações falsas e verdadeiras

# %%
cod = 'not03'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 9199
#
# PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mes… https://t.co/1cXaHFE2ve
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mesmo IRPF pa…
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mesmo IRPF pa…
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mesmo IRPF pa…
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mesmo IRPF pa…
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ✔ Fim do 13o salário
# ✔ Fim do adicional de férias
# ✔ Redução da licença maternidade
# ✔ Mesmo IRPF pa…
# ---
# RT @remuspjr: PROPOSTAS DE BOLSONARO:
# ...

# %% [markdown]
# # Notícia 04:
#
# General Mourão não propôs o confisco da poupança

# %%
cod = 'not04'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 2130
#
# Quem tiver um tempinho, veja com quem se parece esse demagogo que afundou o Brasil e confiscou a poupança dos brasileiros. Foram os piores anos do Brasil na mnha opinião só quem era pai de família naquela época sabe. Sou pela democracia. #Elenão  jamais!  https://www. youtube.com/attribution_li nk?a=rC29IFWf4Yc&u=%2Fwatch%3Fv%3DuIgLowlY8Io%26feature%3Dshare   …
# ---
# Confisco da Poupança vai mudar de nome: "Poupança Solidária".
# Tá certinho! Aff
# #EleSim  #SomosTodosBolsonaro  #Dia07é17  #Bolsonaro17  #ForaPT  #Bolsonaro2018  #ForçaCapitão
# ---
# Isso porque o Mourão ainda não falou do confisco da poupança... Mas vai acabar falando. #elenao  #OFilhoTambemNao  #HADDAD13
# ---
# * #MourãoNosDebatesJá  ele ainda não falou do confisco da poupança... Mas vai acabar falando. #elenao  #OFilhoTambemNao  #HADDAD13 pic.twitter.com/wjEgccgeJi
# ---
# ...

# %% [markdown]
# ## Notícia 05:
#
# Áudio atribuído a Jair Bolsonaro no hospital é falso

# %%
cod = 'not05'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 42
#
# Agora a esquerda foi longe demais, estão divulgando um áudio dizendo que o Bolsonaro tava xingando todo mundo no hospital e dizendo que se não saísse iria perder a eleição!!! Muita mentira envolvida, a que ponto chegamos? #fake  #forçabolsonaro  #EleSIM  #EleSimBolsonaro
# ---
# O áudio atribuído ao Bolsonaro no hospital é um fake MUITO mal feito.
# Tem humorista que imita melhor.
# Que vergonha! Que gente ruim tem nesse Brasil. Manda dar facada e agora imita a voz, errou na faca e na imitação. #e17  #EleSIM  #ForçaBolsonaro  #DireitaSegueDireira
# ---
# ATENÇÃOOO...É FAKE NEWS...!!!
# Áudio com voz idêntica de Bolsonaro dentro do hospital xingando equipe, é MENTIRA...!!!
# #AudioBolsonaro  #Bolsonaro  #Bolsonaro17  #EleSim
#
#  https://www. youtube.com/watch?v=xOlQxu xe7bo   …   https://www. youtube.com/watch?v=xOlQxu xe7bo   …
# ---
# Dá pra ver!
# Esse pessoal do PT só mente!
# ...

# %%
cmd = ("select t.text " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND lower(t.text) like '%udio%' " +
       "AND lower(t.text) like '%hospital%' " +
       "order by t.codtweet asc")
tw05 = query(cmd)
print(len(tw05))
# Out:
# 267

# %%
for t in tw05[:5]:
    print("%s\n------------" % t)
# Out:
# Agora a esquerda foi longe demais, estão divulgando um áudio dizendo que o Bolsonaro tava xingando todo mundo no hospital e dizendo que se não saísse iria perder a eleição!!! Muita mentira envolvida, a que ponto chegamos? #fake  #forçabolsonaro  #EleSIM  #EleSimBolsonaro
# ------------
# O áudio atribuído ao Bolsonaro no hospital é um fake MUITO mal feito.
# Tem humorista que imita melhor.
# Que vergonha! Que gente ruim tem nesse Brasil. Manda dar facada e agora imita a voz, errou na faca e na imitação. #e17  #EleSIM  #ForçaBolsonaro  #DireitaSegueDireira
# ------------
# ATENÇÃOOO...É FAKE NEWS...!!!
# Áudio com voz idêntica de Bolsonaro dentro do hospital xingando equipe, é MENTIRA...!!!
# #AudioBolsonaro  #Bolsonaro  #Bolsonaro17  #EleSim
#
#  https://www. youtube.com/watch?v=xOlQxu xe7bo   …   https://www. youtube.com/watch?v=xOlQxu xe7bo   …
# ------------
# Dá pra ver!
# Esse pessoal do PT só mente!
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '%not05%'")
execSQL(cmd)

# %%
#delete FROM public.analisetweet where codanaliseamostra = 121 and observacao like '%not05%'
cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, 'not05' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND lower(t.text) like '%udio%' " +
       "AND lower(t.text) like '%hospital%' "
      )
execSQL(cmd)

# %%
cmd = ("SELECT codanalisetweet, codanaliseamostra, codclassificacao, codtweet, observacao " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '%not05%'")
tblNot05 = query(cmd)
print(len(tblNot05))
# Out:
# 267

# %% [markdown]
# # Notícia 06:
#
# #Verificamos: Imagem apresentada como ‘capa do kit gay’ não está no material

# %%
cod = 'not06'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 181662
#
# Vejamos: Estando na Esquerda você é comparsa de ladrão a favor de kit gay e por ai vai . Já no Centro você é covarde indeciso joão vai com outros. Agora na Direita você é MITO o CARA o Consagrado. Regra do Parquinho >> Não  sabe brincar não sobe no play #EleNao
# ---
# Não sei qual dos delírios bolsominions é o mais cômico: a  ameaça comunista, o kit gay ou que as manifestações deles tiveram a mesma importância que as do #EleNao
# ---
# Ah mas ele não disse isso...
# Distorceram o que ele disse...
# Mas se você vê bem ele estava querendo dizer outra coisa...
# A briga dele é só contra o kit-gay...
#
# Basta não tem desculpas!!!!! #EleNão  #EleNunca   https://www. facebook.com/hdthiago/posts /2053516901335417   …
# ---
# É LGBT e vai votar no #Elenao ? Não se esqueça de lembrar do kit gay fake que coiso e cia criaram para ESPALHAR ódio contra vcs.
# ---
# Haddad, o pai do kit gay. Esse é o Brasil que eu NÃO QUERO!!!
# #SomosBolsonaro17
# ...

# %%
cmd = ("select count(*) " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND lower(t.text) like '%kit%gay%' "
      )
cnt06 = query(cmd)
print(cnt06)

cmd = ("select t.text " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND lower(t.text) like '%kit%gay%' " +
       "LIMIT 100"
      )
tw06 = query(cmd)
print(len(tw06))
# Out:
# 100

# %%
cnt06
# Out:
# [(181799,)]

# %%
tw06[:20]
# Out:
# [('RT @gabsregui: kit gay é isso aqui, o resto é fake news https://t.co/7QRnglyJr0',),
#  ('RT @gabsregui: kit gay é isso aqui, o resto é fake news https://t.co/7QRnglyJr0',),
#  ('RT @milenereis: “Vídeos desmascaram kit gay, maior fake news de Bolsonaro” (Brasil 247)\nEntenda: quem inventou o “kit gay” de Haddad foi Bo…',),
#  ('RT @psl_mg: Diretor de Associação de Gays, Lésbicas, e Travestis desmascara Haddad sobre a paternidade do “Kit Gay” (Veja o Vídeo) https://…',),
#  ('RT @milenereis: “Vídeos desmascaram kit gay, maior fake news de Bolsonaro” (Brasil 247)\nEntenda: quem inventou o “kit gay” de Haddad foi Bo…',),
#  ('E o PAI do KIT GAY mais uma vez contando mentiras... #FakeNewsDoHaddad',),
#  ('RT @PeloFimDoPT1: Haddad agora nega ser o pai do “Kit Gay” para crianças. Ele foi sim o Ministro da Educação do PT que criou esse lixo que…',),
#  ('RT @gabsregui: kit gay é isso aqui, o resto é fake news https://t.co/7QRnglyJr0',),
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '%not06%'")
execSQL(cmd)

# %%
cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, 'not06' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND lower(t.text) like '%kit%gay%' "
      )
execSQL(cmd)

# %%
cmd = ("SELECT codanalisetweet, codanaliseamostra, codclassificacao, codtweet, observacao " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '%not06%'")
tblNot05 = query(cmd)
print(len(tblNot05))
# Out:
# 181799

# %% [markdown]
# # Notícia 07:
#
# Projeto não torna a pedofilia um ato legal e nem tem participação de Haddad

# %%
cod = 'not07'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 56
#
# RT @efarsas: Novo no E-farsas:  PL 236/2012 de Fernando Haddad torna a pedofilia um ato legal? https://t.co/aFDqq3EbPX
# ---
# Você recebeu a imagem sobre a PL 236/2012, que “legaliza a pedofilia” e tem a logo do Haddad? Então...
#
# Ela é de au… https://t.co/LOCkM8yfuG
# ---
# RT @MoitaRock: Você recebeu a imagem sobre a PL 236/2012, que “legaliza a pedofilia” e tem a logo do Haddad? Então...
#
# Ela é de autoria do…
# ---
# RT @MoitaRock: Você recebeu a imagem sobre a PL 236/2012, que “legaliza a pedofilia” e tem a logo do Haddad? Então...
#
# Ela é de autoria do…
# ---
# RT @MoitaRock: Você recebeu a imagem sobre a PL 236/2012, que “legaliza a pedofilia” e tem a logo do Haddad? Então...
#
# Ela é de autoria do…
# ---
# RT @MoitaRock: Você recebeu a imagem sobre a PL 236/2012, que “legaliza a pedofilia” e tem a logo do Haddad? Então...
#
# Ela é de autoria do…
# ---
# ...

# %%
filtro = "AND lower(t.text) like '%236%' AND lower(t.text) like '%pedofilia%' "
filtro = "AND lower(t.text) like '%pedofilia%' AND (lower(t.text) like '%projeto%' or lower(t.text) like '%236%')"
cod = "not07"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws07 = query(cmd)

for tw in tws07:
    print(tw)
# Out:
# Total de noticias: 1650
#
# ('RT @estadaoverifica: Projeto não torna a pedofilia um ato legal e nem tem participação de Haddad #Comprova https://t.co/u6TwZX8TYt',)
# ('RT @UOL: Fotografia circula em redes sociais | Projeto não torna pedofilia um ato legal nem tem a participação de Haddad https://t.co/wwd70…',)
# ('RT @GauchaZH: O projeto de lei em questão nada tem a ver com legalização da pedofilia e tramita no Congresso Nacional sob relatoria de um s…',)
# ('RT @guilouress: Eu entro no facebook e tá la as fake news sobre existir projeto de lei do Pt a favor da pedofilia. Mano, se esses Cristãos…',)
# ('RT @UOLNoticias: Projeto não torna a pedofilia um ato legal nem tem participação de Haddad #comprova  https://t.co/bddz58GQ54',)
# ('RT @UOLNoticias: Projeto não torna a pedofilia um ato legal nem tem participação de Haddad #comprova  https://t.co/bddz58GQ54',)
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-12-989c3da443ef> in <module>()
#       8        "where at.codamostra = 99 " +
#       9        filtro )
# ---> 10 execSQL(cmd)
#      11
#      12 cmd = ("SELECT count(*) " +
#
# ~/projetos/absa/aux/postgres.py in execSQL(comando)
#      15     conn.rollback()
#      16     qry = conn.cursor()
# ---> 17     ok = qry.execute(comando)
#      18     conn.commit()
#      19     return ok
#
# IntegrityError: ERRO:  duplicar valor da chave viola a restrição de unicidade "analisetweet_codanaliseamostra_codtweet_codclassificacao_key"
# DETAIL:  Chave (codanaliseamostra, codtweet, codclassificacao)=(121, 163146833, 1) já existe.

# %% [markdown]
# # Notícia 08:
#
# "Mamadeiras eróticas" não foram distribuídas em creches pelo PT

# %%
cod = 'not08'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 10580
#
# Fotos e vídeos mostrando milhares e de pessoas em atos #EleNão  pelo BR: montagem mentira fake news
#
# Montagem corrente de zap falando que Haddad distribui mamadeiras em formato de pênis: vdd
# ---
# Mama África
# A minha mãe
# É MÃE SOLTEIRA
# E tem que
# fazer mamadeira
# TODO DIA
# ALÉM DE TRABALHAR
# Como empacotadeira
# Nas Casas Bahia
# #TodoDiaÉDiaDe  #EleNão
# ---
# Não eh pq eu sou #elenão  que eu gosto do pt ou do Lula deus me dibre
# Eu gosto de maconha, beijar rapazes, cheirar bico de mamadeira... Eleição eu escolho o menos pior *ainda não encontrei*
# ---
# Comprova: mamadeiras eróticas não foram entregues em creches pelo PT  http:// a.msn.com/01/pt-br/BBNEQ 1X?ocid=st   …  É CADA UMA Q INVENTAM VIU! KKK #ELENAO
# ---
# As pessoas de bem são tão criminosas que tão comprando mamadeira de sex shop pra tocar o terror moral contra a esquerda. #EleNão   https:// projetocomprova.com.br/post/re_2B5W8X Yj0Jwb   …
# ---
# ...

# %%
filtro = "AND lower(t.text) like '%mamadeira%' "
cod = "not08"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 10715
#
# ('RT @heisenboff: no passado: "em 2018 teremos carros voadores"\n\nem 2018: tendo que desmentir fake news que diz que distribuíram mamadeira co…',)
# ('RT @heisenboff: no passado: "em 2018 teremos carros voadores"\n\nem 2018: tendo que desmentir fake news que diz que distribuíram mamadeira co…',)
# ('RT @Itspedrito: Dificil entender um bolsominion:\n\n- Haddad tava distribuindo mamadeira com formato de piroca para crianças!\n-  SÓ PODIA SER…',)
# ('espero que o haddad ganhe pois eu quero aquela mamadeira de piroca',)
# ('RT @adamastaquio: Me desculpem, mas quem inventa e quem acredita em mamadeira com bico em forma de pênis são pedófilos e não sabem. \n\nOu sa…',)
# ('RT @Itspedrito: bolsonariano acredita ate em mamadeira de piroca distribuida pelo MEC mas nao acredita em nenhuma noticia contra bolsonaro,…',)
# ('RT @Pragmatismo_: Apoiadores de Bolsonaro espalham boato sobre "mamadeira erótica de Fernando Haddad" e mensagem viraliza nas redes e em gr…',)
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd1 = ("SELECT at1.codtweet " +
       "FROM analisetweet at1 " +
       "INNER JOIN tweet t1 ON t1.codtweet = at1.codtweet " +
       "WHERE lower(t1.text) like '%mamadeira%'")
print(cmd1)
print('---')

cmd = ("INSERT INTO analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "SELECT 121, 1, t.codtweet, '" + cod + "' " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       "AND at.codtweet NOT IN (" + cmd1 + ") " +
       filtro )
print(cmd)
print('---')
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '%" + cod + "%'")
total = query(cmd)
print(total[0])
# Out:
# SELECT at1.codtweet FROM analisetweet at1 INNER JOIN tweet t1 ON t1.codtweet = at1.codtweet WHERE lower(t1.text) like '%mamadeira%'
# ---
# INSERT INTO analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) SELECT 121, 1, t.codtweet, 'not08' FROM amostratweet at INNER JOIN tweet t ON t.codtweet = at.codtweet WHERE at.codamostra = 99 AND at.codtweet NOT IN (SELECT at1.codtweet FROM analisetweet at1 INNER JOIN tweet t1 ON t1.codtweet = at1.codtweet WHERE lower(t1.text) like '%mamadeira%') AND lower(t.text) like '%mamadeira%'
# ---
# (10580,)
# (10715,)

# %%
cmd = ("SELECT t.text, at.observacao FROM analisetweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE 1 = 1 " + filtro)
tweet = query(cmd)
print(len(tweet))
print()
for t in tweet:
    print("%s\n%s\n---" % (t[1],t[0]))
# Out:
# 135
#
# not06
# Vcs  é tão imbecil de acreditar que estão distribuindo kit gay, mamadeira erótica e Barbie travesti em escolas.
# O Governo  não  estão distribuindo  nem merenda direito que é o básico imagine o resto.
# #EleNão  #RT
# ---
# not06
# RT @venussred: esses desgraçados recebem fake news sobre kit gay e mamadeira com bico em formato de pênis e compartilham como verdade absol…
# ---
# not06
# RT @debnery: @anacronices @forastieri Nunca vi uma eleição tão baseada em sexo quanto essa, é kit gay inexistente, fake news de mamadeira e…
# ---
# not06
# RT @debnery: @anacronices @forastieri Nunca vi uma eleição tão baseada em sexo quanto essa, é kit gay inexistente, fake news de mamadeira e…
# ---
# not06
# Kit gay, as aulas de masturbação no ensino infantil e as mamadeiras-pênis. Complicadíssimo ter que voltar láaaaaaaa… https://t.co/LTYPOKDlA8
# ---
# not06
# ...

# %%
cmd1 = ("SELECT at.codanalisetweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE 1 = 1 " + filtro)

cmd = "UPDATE codanalisetweet SET observacao = 'not06;not08' WHERE codanalisetweet IN (" + cmd1 + ")"

print(cmd)
execSQL(cmd)
# Out:
# SELECT at.codanalisetweet FROM analisetweet at INNER JOIN tweet t ON t.codtweet = at.codtweet WHERE 1 = 1 AND lower(t.text) like '%mamadeira%'
# UPDATE codanalisetweet SET observacao = 'not06;not08' WHERE codanalisetweet IN (SELECT at.codanalisetweet FROM analisetweet at INNER JOIN tweet t ON t.codtweet = at.codtweet WHERE 1 = 1 AND lower(t.text) like '%mamadeira%' )

# %% [markdown]
# # Notícia 09:
#
# Vídeo em que Haddad diz que eleição acabou é de 2016

# %%
cod = 'not09'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 1110
#
# RT @cidapitanga: Folha reconhece que foi incapaz de olhar seus próprios leitores.
# JOGOU A TOALHA
#
# PRIMEIRO TURNO GENTE!!
#
# "A Folha de S. P…
# ---
# RT @Dom_Rezende33: Até Ibope já jogou a toalha
#
# Votos válidos:
# Bolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4
# ---
# RT @Dom_Rezende33: Até Ibope já jogou a toalha
#
# Votos válidos:
# Bolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4
# ---
# RT @Dom_Rezende33: Até Ibope já jogou a toalha
#
# Votos válidos:
# Bolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4
# ---
# RT @Dom_Rezende33: Até Ibope já jogou a toalha
#
# Votos válidos:
# Bolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4
# ---
# RT @TerciottiNt: O Ibope jogou a toalha...kkkkk....já era...não terá  segundo turno...#BolsonaroAmorDoBrasil https://t.co/y4g1Eipr6L
# ---
# RT @Dom_Rezende33: Até Ibope já jogou a toalha
#
# Votos válidos:
# Bolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4
# ---
# ...

# %%
filtro = "AND lower(t.text) like '%jogou%' AND lower(t.text) like '%toalha%' "
cod = "not09"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 1110
#
# ('RT @cidapitanga: Folha reconhece que foi incapaz de olhar seus próprios leitores.\nJOGOU A TOALHA \n\nPRIMEIRO TURNO GENTE!!\n\n"A Folha de S. P…',)
# ('RT @Dom_Rezende33: Até Ibope já jogou a toalha\n\nVotos válidos:\nBolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4',)
# ('RT @Dom_Rezende33: Até Ibope já jogou a toalha\n\nVotos válidos:\nBolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4',)
# ('RT @Dom_Rezende33: Até Ibope já jogou a toalha\n\nVotos válidos:\nBolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4',)
# ('RT @Dom_Rezende33: Até Ibope já jogou a toalha\n\nVotos válidos:\nBolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4',)
# ('RT @TerciottiNt: O Ibope jogou a toalha...kkkkk....já era...não terá  segundo turno...#BolsonaroAmorDoBrasil https://t.co/y4g1Eipr6L',)
# ('RT @Dom_Rezende33: Até Ibope já jogou a toalha\n\nVotos válidos:\nBolsonaro 59% x 41% Haddad https://t.co/64IdlpdDS4',)
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# (1110,)

# %% [markdown]
# # Notícia 10:
#
# "Ao completar 5 anos de idade, a criança passa a ser propriedade do Estado! Cabe a nós decidir se
# menino será menina e vice-versa! Aos pais cabe acatar nossa decisão respeitosamente! Sabemos
# o que é melhor para as crianças!"

# %%
cod = 'not10'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 478
#
# RT @AngelJones_1330: 1. Fake News!
#
# - É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero esc…
# ---
# misericordia o povo compartilhando no fb que as crianças que completam 5 anos serão propriedade do Estado no governo do Haddad AAAAAAAAAAA
# ---
# RT @jornalextra: É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero escolhido. https://t.co/l…
# ---
# É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/o6Bu6KZvdk
# ---
# É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/jAlUxaG0mD
# ---
# É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero escolhido https://t.co/eltRc4vPRH
# ---
# É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/PmKUSRbHoW
# ---
# RT @AngelJones_1330: 1. Fake News!
#
# ...

# %%
filtro = "AND lower(t.text) like '%crian%' AND lower(t.text) like '%propriedade%' AND lower(t.text) like '%estado%' "
cod = "not10"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 480
#
# ('RT @AngelJones_1330: 1. Fake News! \n\n- É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero esc…',)
# ('misericordia o povo compartilhando no fb que as crianças que completam 5 anos serão propriedade do Estado no governo do Haddad AAAAAAAAAAA',)
# ('RT @jornalextra: É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero escolhido. https://t.co/l…',)
# ('É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/o6Bu6KZvdk',)
# ('É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/jAlUxaG0mD',)
# ('É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos e pode ter seu gênero escolhido https://t.co/eltRc4vPRH',)
# ('É #FAKE que Haddad disse que criança vira propriedade do Estado aos 5 anos https://t.co/PmKUSRbHoW',)
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       "AND t.codtweet <> '157242694' " +
       "AND t.codtweet <> '165620735' " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# (478,)

# %% [markdown]
# # Notícia 11:
#
# Patrícia Pillar desmente meme e diz que nunca sofreu agressão

# %%
cod = 'not11'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 30
#
# # ciroagressor  #foraciro  #patriciapillar
# #voto17  #Bolsonaro2018  #B17  #meucandidato  #MulherescomBolsonaro  #Elesim  #SouBolsonaro  #FamiliaBolsonaro  #direitaseguedireita pic.twitter.com/axmvOIYhtn
# ---
# Ciro batia na Patricia Pillar
# Haddad vai escolher gênero das crianças aos seis anos.
# Marina vai trocar crianças abortadas por árvores.
# Amoedo vai dar cartão de crédito do Itaú só pros pobres se endividarem.
#
# Tudo fato.
#
# Peido de Bolsonaro fede. Fake news. #EleNão
# ---
# Tipo, Patricia Pillar também desmentiu agressões do Ciro e os coisodivos(as) insistem na fake news.
# A palavra de terceiros vale mais do que a dos envolvidos?
# Quanto a ex coisocônjuge, ela deve ter vendido a sua dignidade por um espaço na politica.
# #EleNão
# ---
# @cirogomes Além do escândalo da agressão a Patricia Pillar e mandar prender um jornalista que te fez uma pergunta,… https://t.co/BdxXUJ0z82
# ---
# ...

# %%
filtro = "AND lower(t.text) like '%pillar%' AND (lower(t.text) like '%batia%' or lower(t.text) like '%agress%')"
cod = "not11"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 30
#
# ('# ciroagressor  #foraciro  #patriciapillar \n#voto17  #Bolsonaro2018  #B17  #meucandidato  #MulherescomBolsonaro  #Elesim  #SouBolsonaro  #FamiliaBolsonaro  #direitaseguedireita pic.twitter.com/axmvOIYhtn',)
# ('Ciro batia na Patricia Pillar\nHaddad vai escolher gênero das crianças aos seis anos. \nMarina vai trocar crianças abortadas por árvores.\nAmoedo vai dar cartão de crédito do Itaú só pros pobres se endividarem. \n\nTudo fato. \n\nPeido de Bolsonaro fede. Fake news. #EleNão',)
# ('Tipo, Patricia Pillar também desmentiu agressões do Ciro e os coisodivos(as) insistem na fake news.\nA palavra de terceiros vale mais do que a dos envolvidos?\nQuanto a ex coisocônjuge, ela deve ter vendido a sua dignidade por um espaço na politica. \n#EleNão',)
# ('@cirogomes Além do escândalo da agressão a Patricia Pillar e mandar prender um jornalista que te fez uma pergunta,… https://t.co/BdxXUJ0z82',)
# ...

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# (30,)

# %% [markdown]
# # Notícia 12:
#
# Não é verdade que marido de Marina Silva é 'um dos maiores desmatadores da Amazônia'

# %%
cod = 'not12'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 1
#
# Marina, casada com um dos maiores desmatadores da Amazônia ( como Ministra do meio ambiente, consegue as licenças),… https://t.co/D8yabTXjrF
# ---

# %%
filtro = "AND lower(t.text) like '%desmatador%' AND lower(t.text) like '%marina%' "
cod = "not12"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 1
#
# ('Marina, casada com um dos maiores desmatadores da Amazônia ( como Ministra do meio ambiente, consegue as licenças),… https://t.co/D8yabTXjrF',)

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# (1,)

# %% [markdown]
# # Notícia 13:
#
# Ciro Gomes não garantiu que vai diminuir salários de médicos; site distorce informações

# %%
cod = 'not13'
cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print("Tota de tweets: %s\n" % total[0][0])
cmd = ("SELECT t.text as tweet " +
       "FROM analisetweet at " +
       "INNER JOIN tweet t ON at.codtweet = t.codtweet "
       "where codanaliseamostra = 121 and observacao like '" + cod + "' LIMIT 10")
tws = query(cmd)
for t in tws:
    print("%s\n---" % t)
# Out:
# Tota de tweets: 1
#
# Acabei de ver Ciro Gomes prometeu baixar os salários dos médicos caso seja eleito? - Clique para ver também ☛… https://t.co/jBRwAftvkk
# ---

# %%
filtro = "AND lower(t.text) like '%sal%rio%' AND lower(t.text) like '%dico%'  AND lower(t.text) like '%ciro%'"
cod = "not13"

cmd = ("SELECT COUNT(*) " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro
      )
count = query(cmd)
print("Total de noticias: %s\n" % count[0])

cmd = ("SELECT t.text " +
       "FROM amostratweet at " +
       "INNER JOIN tweet t ON t.codtweet = at.codtweet " +
       "WHERE at.codamostra = 99 " +
       filtro +
       "LIMIT 100")
tws = query(cmd)

for tw in tws:
    print(tw)
# Out:
# Total de noticias: 1
#
# ('Acabei de ver Ciro Gomes prometeu baixar os salários dos médicos caso seja eleito? - Clique para ver também ☛… https://t.co/jBRwAftvkk',)

# %%
cmd = ("DELETE FROM analisetweet WHERE codanaliseamostra = 121 AND observacao like '" + cod + "'")
execSQL(cmd)

cmd = ("INSERT INTO public.analisetweet(codanaliseamostra, codclassificacao, codtweet, observacao) " +
       "select 121, 1, t.codtweet, '" + cod + "' " +
       "from amostratweet at " +
       "inner join tweet t on t.codtweet = at.codtweet " +
       "where at.codamostra = 99 " +
       filtro )
execSQL(cmd)

cmd = ("SELECT count(*) " +
       "FROM public.analisetweet " +
       "where codanaliseamostra = 121 and observacao like '" + cod + "'")
total = query(cmd)
print(total[0])
# Out:
# (1,)
